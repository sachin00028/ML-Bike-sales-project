# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin00028/ML-Project/blob/main/UsedBike_sale_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/BIKE DETAILS.csv')
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df.tail()
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1056     500000            52000.0
# 1057      33000            51000.0
# 1058      35000            57000.0
# 1059      53000            58000.0
# 1060      92233            75000.0

# %%
df.isna().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df['name'].value_counts().head(20)
# Out:
# Bajaj Pulsar 150                 41
# Royal Enfield Classic 350        27
# Honda Activa [2000-2015]         23
# Honda CB Hornet 160R             22
# Bajaj Pulsar 180                 20
# Royal Enfield Thunderbird 350    19
# Hero Honda Splendor Plus         17
# Bajaj Discover 125               16
# Yamaha FZ S V 2.0                16
# Honda Activa 3G                  15
# Honda Shine                      15
# Honda CB Unicorn 150             14
# TVS Apache RTR 160               14
# Bajaj Pulsar 135 LS              13
# Honda Activa 5G                  12
# Yamaha FZ16                      12
# Bajaj Pulsar 150 [2001-2011]     11
# Hero Glamour 125                 11
# Bajaj Discover 100               11
# Hero Honda CBZ extreme           11
# Name: name, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# 1st owner    924
# 2nd owner    123
# 3rd owner     11
# 4th owner      3
# Name: owner, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2017    133
# 2018    131
# 2016    107
# 2015    100
# 2014     91
# 2019     86
# 2013     73
# 2012     70
# 2011     61
# 2010     60
# 2007     29
# 2008     28
# 2009     28
# 2006     20
# 2005     14
# 2000      6
# 2004      5
# 2002      3
# 2020      3
# 1998      3
# 1997      2
# 2001      2
# 1988      1
# 1999      1
# 1991      1
# 2003      1
# 1993      1
# 1995      1
# Name: year, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# Individual    1055
# Dealer           6
# Name: seller_type, dtype: int64

# %% [markdown]
# Data Visualisation

# %%
top_10=df['name'].value_counts().head(10)
sns.barplot(x=top_10,y=top_10.index)
plt.ylabel('Bike Names')
plt.xlabel('Count')
plt.title('Top 10 Bikes for sale')
# Out:
# Text(0.5, 1.0, 'Top 10 Bikes for sale')

# %%
sns.countplot(x=df['owner'],data=df)

# %%
sns.countplot(x=df['seller_type'],data=df)

# %%
# Relation between Kilometers Driven and Selling Price

sns.jointplot(x='km_driven',y='selling_price',data=df,kind='hex',color='r')

# %%
# Relation between year of the bike and Selling price

sns.jointplot(x='year',y='selling_price',data=df,kind='hex',color='g')

# %%
df['ex_showroom_price'].fillna(np.round(df['ex_showroom_price'].mean(),2),inplace=True)
sns.distplot(df['ex_showroom_price'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Data Preprocessing

# %%
np.round(df['ex_showroom_price'],2)
# Out:
# 0        87958.71
# 1        87958.71
# 2       148114.00
# 3        89643.00
# 4        87958.71
#           ...
# 1056     52000.00
# 1057     51000.00
# 1058     57000.00
# 1059     58000.00
# 1060     75000.00
# Name: ex_showroom_price, Length: 1061, dtype: float64

# %%
dummy=pd.get_dummies(df[['owner','seller_type',]],drop_first=True)
dummy
# Out:
#       owner_2nd owner  owner_3rd owner  owner_4th owner  \
# 0                   0                0                0
# 1                   0                0                0
# 2                   0                0                0
# 3                   0                0                0
# 4                   1                0                0
# ...               ...              ...              ...
# 1056                0                0                0
# 1057                0                0                0
# 1058                1                0                0
# 1059                0                0                0
# 1060                0                0                0
#
#       seller_type_Individual
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...                      ...
# 1056                       1
# 1057                       1
# ...

# %%
dfe=pd.concat([df,dummy],axis=1)
dfe
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price  owner_2nd owner  \
# ...

# %%
dfe=dfe.drop(['seller_type','owner'],axis=1)
dfe
# Out:
#                                      name  selling_price  year  km_driven  \
# 0               Royal Enfield Classic 350         175000  2019        350
# 1                               Honda Dio          45000  2017       5650
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018      12000
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015      23000
# 4                   Yamaha SZ [2013-2014]          20000  2011      21000
# ...                                   ...            ...   ...        ...
# 1056                            Activa 3g          17000  2010     500000
# 1057                     Honda CB twister          16000  2012      33000
# 1058                   Bajaj Discover 125          15000  2013      35000
# 1059                       Honda CB Shine          12000  2009      53000
# 1060                     Bajaj Pulsar 150          10000  2008      92233
#
#       ex_showroom_price  owner_2nd owner  owner_3rd owner  owner_4th owner  \
# ...

# %%
# Since Hero honda is the brand which has been changed. So it is renamed to a new model name as Hero

def bike_model(model_name,del_hero_honda=False):
  lst_model=[]
  if del_hero_honda:
    for i in dfe['name']:
      if model_name in i and 'Hero' not in i:
        lst_model.append(i)
    return lst_model

  else:
    for i in dfe['name']:
      if model_name in i:
        lst_model.append(i)
    return lst_model

# %%
# Categorising each bike name as popular brands

royal_enfield = bike_model('Royal Enfield')
ktm = bike_model('KTM')
yamaha = bike_model('Yamaha')
honda = bike_model('Honda',del_hero_honda=True)
suzuki = bike_model('Suzuki')
hero = bike_model('Hero')
tvs = bike_model('TVS')
bajaj = bike_model('Bajaj')

# %%
def brand(i):
  if i in royal_enfield:
    return 'Royal Enfield'
  elif i in ktm:
    return 'KTM'
  elif i in yamaha:
    return 'Yamaha'
  elif i in honda:
    return 'Honda'
  elif i in suzuki:
    return 'Suzuki'
  elif i in hero:
    return 'Hero'
  elif i in tvs:
    return 'TVS'
  elif i in bajaj:
    return 'Bajaj'
  else:
    return 'Others'

# %%
# Categorising each popular brands under one head as Brands

dfe['brand']=dfe['name'].apply(lambda x:brand(x))

# %%
dfe.head()
# Out:
#                                   name  selling_price  year  km_driven  \
# 0            Royal Enfield Classic 350         175000  2019        350
# 1                            Honda Dio          45000  2017       5650
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018      12000
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015      23000
# 4                Yamaha SZ [2013-2014]          20000  2011      21000
#
#    ex_showroom_price  owner_2nd owner  owner_3rd owner  owner_4th owner  \
# 0           87958.71                0                0                0
# 1           87958.71                0                0                0
# 2          148114.00                0                0                0
# 3           89643.00                0                0                0
# 4           87958.71                1                0                0
#
#    seller_type_Individual          brand
# 0                       1  Royal Enfield
# ...

# %%
dfe=dfe.drop(['name'],axis=1)
dfe.head()
# Out:
#    selling_price  year  km_driven  ex_showroom_price  owner_2nd owner  \
# 0         175000  2019        350           87958.71                0
# 1          45000  2017       5650           87958.71                0
# 2         150000  2018      12000          148114.00                0
# 3          65000  2015      23000           89643.00                0
# 4          20000  2011      21000           87958.71                1
#
#    owner_3rd owner  owner_4th owner  seller_type_Individual          brand
# 0                0                0                       1  Royal Enfield
# 1                0                0                       1          Honda
# 2                0                0                       1  Royal Enfield
# 3                0                0                       1         Yamaha
# 4                0                0                       1         Yamaha

# %%
dummy1=pd.get_dummies(dfe[['brand']],drop_first=True)
dummy1.head()
# Out:
#    brand_Hero  brand_Honda  brand_KTM  brand_Others  brand_Royal Enfield  \
# 0           0            0          0             0                    1
# 1           0            1          0             0                    0
# 2           0            0          0             0                    1
# 3           0            0          0             0                    0
# 4           0            0          0             0                    0
#
#    brand_Suzuki  brand_TVS  brand_Yamaha
# 0             0          0             0
# 1             0          0             0
# 2             0          0             0
# 3             0          0             1
# 4             0          0             1

# %%
df1=pd.concat([dfe,dummy1],axis=1)
df1.head()
# Out:
#    selling_price  year  km_driven  ex_showroom_price  owner_2nd owner  \
# 0         175000  2019        350           87958.71                0
# 1          45000  2017       5650           87958.71                0
# 2         150000  2018      12000          148114.00                0
# 3          65000  2015      23000           89643.00                0
# 4          20000  2011      21000           87958.71                1
#
#    owner_3rd owner  owner_4th owner  seller_type_Individual          brand  \
# 0                0                0                       1  Royal Enfield
# 1                0                0                       1          Honda
# 2                0                0                       1  Royal Enfield
# 3                0                0                       1         Yamaha
# 4                0                0                       1         Yamaha
#
#    brand_Hero  brand_Honda  brand_KTM  brand_Others  brand_Royal Enfield  \
# ...

# %%
df1=df1.drop(['brand'],axis=1)
df1
# df1 is now a pure dataset which had been finished with all the preprocessing steps
# Out:
#       selling_price  year  km_driven  ex_showroom_price  owner_2nd owner  \
# 0            175000  2019        350           87958.71                0
# 1             45000  2017       5650           87958.71                0
# 2            150000  2018      12000          148114.00                0
# 3             65000  2015      23000           89643.00                0
# 4             20000  2011      21000           87958.71                1
# ...             ...   ...        ...                ...              ...
# 1056          17000  2010     500000           52000.00                0
# 1057          16000  2012      33000           51000.00                0
# 1058          15000  2013      35000           57000.00                1
# 1059          12000  2009      53000           58000.00                0
# 1060          10000  2008      92233           75000.00                0
#
#       owner_3rd owner  owner_4th owner  seller_type_Individual  brand_Hero  \
# ...

# %%
x=df1.iloc[:,1:].values
y=df1.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[2.010000e+03, 3.570000e+04, 8.795871e+04, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [2.010000e+03, 6.000000e+04, 5.385700e+04, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [2.012000e+03, 4.000000e+04, 8.795871e+04, ..., 0.000000e+00,
#         0.000000e+00, 1.000000e+00],
#        ...,
#        [2.018000e+03, 7.000000e+03, 1.805250e+05, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [2.010000e+03, 2.600000e+04, 7.500000e+04, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [2.011000e+03, 1.200000e+04, 5.890000e+05, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00]])

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 40000. ,  25000. ,  18500. ,  25000. ,  90000. ,  42000. ,
#         40000. ,  30000. ,  30000. ,  35000. ,  35000. ,  45000. ,
#        110000. ,  45000. ,  10000. ,  40000. ,  60000. , 120000. ,
#         40000. ,  60000. ,  35000. ,  65000. ,  40000. ,  25000. ,
#         60000. ,  25000. ,  10000. ,  12000. ,  55000. , 165000. ,
#         45000. ,  18000. ,  18000. ,  95000. ,  30000. ,  10000. ,
#         69000. ,  30000. ,  65000. ,  50000. , 160000. ,  30000. ,
#         40000. ,  57000. ,  45000. ,  40000. ,  18000. ,  70000. ,
#         30000. ,  15000. ,  40000. , 135000. ,  55000. , 100000. ,
#         70000. , 150000. , 160000. ,  65000. ,  50000. ,  95000. ,
#         21000. ,  25000. ,  40000. ,  35000. ,  45000. ,  23000. ,
#         25000. ,  40000. ,  98000. , 123000. ,   8000. ,  30000. ,
#        150000. , 140000. ,  62000. ,  25000. ,  28000. ,  23000. ,
#         35000. , 105000. ,  25000. ,  95000. ,  60000. , 365000. ,
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('MAE % ',mean_absolute_percentage_error(y_test,y_pred))
print('r2 score ',r2_score(y_test,y_pred))
# Out:
# MAE %  0.29981768372653156
# r2 score  0.7896161051696209

# %% [markdown]
# Predicted Data

# %%
df2=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred})
df2.head(20)
# Out:
#     Actual_value  Predicted_value
# 0          38000          40000.0
# 1          16000          25000.0
# 2          12000          18500.0
# 3          27000          25000.0
# 4         100000          90000.0
# 5          23500          42000.0
# 6          25000          40000.0
# 7          22000          30000.0
# 8          30000          30000.0
# 9          45000          35000.0
# 10         30000          35000.0
# 11         18000          45000.0
# 12        105000         110000.0
# 13         50000          45000.0
# 14         70000          10000.0
# 15         45000          40000.0
# 16         60000          60000.0
# 17         65000         120000.0
# 18         40000          40000.0
# 19        100000          60000.0

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 4.92773835e+04,  3.46437874e+04,  1.26339135e+04,  4.71503339e+04,
#         7.94594257e+04,  3.08893162e+04,  4.77644954e+04,  2.75702345e+04,
#         2.74959986e+04,  3.49670812e+04,  2.51641563e+04,  3.14244408e+04,
#         1.75611282e+05,  3.89963586e+04,  2.83775782e+04,  4.90728853e+04,
#         5.40427428e+04,  7.74805764e+04,  3.35738615e+04,  8.65517225e+04,
#         4.25603637e+04,  6.20041043e+04,  6.33926303e+04,  1.64685608e+04,
#         6.80914333e+04,  1.66129043e+04,  1.20857540e+04,  2.56873571e+04,
#         5.48725469e+04,  1.59134573e+05,  4.25997110e+04,  2.55675508e+04,
#         2.57934961e+04,  6.69626697e+04,  4.21413275e+04,  1.96575141e+04,
#         6.12714807e+04,  3.49069432e+04,  4.58911078e+04,  4.81725285e+04,
#         1.39910267e+05,  2.64126524e+04,  4.08737941e+04,  5.35950461e+04,
#         4.92830952e+04,  2.57526981e+04,  1.85340456e+04,  5.98355165e+04,
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('MAE % ',mean_absolute_percentage_error(y_test,y_pred))
print('r2 score ',r2_score(y_test,y_pred))
# Out:
# MAE %  0.359320103110993
# r2 score  0.7802432599002701

# %%
df3=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred})
df3.head(20)
# Out:
#     Actual_value  Predicted_value
# 0          38000     49277.383526
# 1          16000     34643.787423
# 2          12000     12633.913525
# 3          27000     47150.333923
# 4         100000     79459.425688
# 5          23500     30889.316187
# 6          25000     47764.495444
# 7          22000     27570.234520
# 8          30000     27495.998645
# 9          45000     34967.081233
# 10         30000     25164.156336
# 11         18000     31424.440817
# 12        105000    175611.281664
# 13         50000     38996.358602
# 14         70000     28377.578161
# 15         45000     49072.885314
# 16         60000     54042.742783
# 17         65000     77480.576420
# 18         40000     33573.861519
# 19        100000     86551.722508

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

regressor = RandomForestRegressor(n_estimators=100,max_depth=10,random_state=42)
regressor.fit(x_train,y_train)

y_pred =regressor.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('MAE % ',mean_absolute_percentage_error(y_test,y_pred))
print('r2 score ',r2_score(y_test,y_pred))
# Out:
# MAE %  0.26188667672420884
# r2 score  0.8618097681553366

# %%
df4=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred})
df4.head(20)
# Out:
#     Actual_value  Predicted_value
# 0          38000     45481.030347
# 1          16000     22110.802581
# 2          12000     18799.871911
# 3          27000     28168.560610
# 4         100000     90994.024454
# 5          23500     28782.124149
# 6          25000     36667.747621
# 7          22000     24392.659381
# 8          30000     30600.960875
# 9          45000     37256.861265
# 10         30000     25300.463182
# 11         18000     42114.742447
# 12        105000    133730.000000
# 13         50000     47025.143807
# 14         70000     44502.182875
# 15         45000     47385.550980
# 16         60000    102854.936869
# 17         65000     84694.211232
# 18         40000     35097.772210
# 19        100000     86195.919040
